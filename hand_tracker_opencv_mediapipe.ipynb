# %%
import sys
!"{sys.executable}" -m pip install opencv-python mediapipe
# Out:
# Requirement already satisfied: opencv-python in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: mediapipe in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (0.10.35)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (2.0.0)
# Requirement already satisfied: absl-py~=2.3 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (2.4.0)
# Requirement already satisfied: certifi in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (2024.6.2)
# Requirement already satisfied: sounddevice~=0.5 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (0.5.5)
# Requirement already satisfied: flatbuffers~=25.9 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (25.12.19)
# Requirement already satisfied: opencv-contrib-python in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (4.13.0.92)
# Requirement already satisfied: matplotlib in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (3.9.1)
# Requirement already satisfied: cffi in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from sounddevice~=0.5->mediapipe) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from cffi->sounddevice~=0.5->mediapipe) (2.22)
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install "mediapipe==0.10.14"
# Out:
# Collecting mediapipe==0.10.14
#   Using cached mediapipe-0.10.14-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# Requirement already satisfied: absl-py in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from mediapipe==0.10.14) (2.4.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from mediapipe==0.10.14) (23.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from mediapipe==0.10.14) (25.12.19)
# Requirement already satisfied: jax in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from mediapipe==0.10.14) (0.10.1)
# Requirement already satisfied: jaxlib in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from mediapipe==0.10.14) (0.10.1)
# Requirement already satisfied: matplotlib in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from mediapipe==0.10.14) (3.9.1)
# Requirement already satisfied: numpy in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from mediapipe==0.10.14) (2.0.0)
# Requirement already satisfied: opencv-contrib-python in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from mediapipe==0.10.14) (4.13.0.92)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from mediapipe==0.10.14) (4.25.9)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from mediapipe==0.10.14) (0.5.5)
# Requirement already satisfied: cffi in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from sounddevice>=0.4.4->mediapipe==0.10.14) (1.16.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe==0.10.14) (0.5.1)
# Requirement already satisfied: opt_einsum in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe==0.10.14) (3.4.0)
# Requirement already satisfied: scipy>=1.14 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe==0.10.14) (1.15.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe==0.10.14) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe==0.10.14) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe==0.10.14) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe==0.10.14) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe==0.10.14) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe==0.10.14) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe==0.10.14) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe==0.10.14) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe==0.10.14) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\sarmili chanda\appdata\local\programs\python\python312\lib\site-packages (from cffi->sounddevice>=0.4.4->mediapipe==0.10.14) (2.22)
# Using cached mediapipe-0.10.14-cp312-cp312-win_amd64.whl (50.8 MB)
# Installing collected packages: mediapipe
#   Attempting uninstall: mediapipe
#     Found existing installation: mediapipe 0.10.35
#     Uninstalling mediapipe-0.10.35:
#       Successfully uninstalled mediapipe-0.10.35
# Successfully installed mediapipe-0.10.14
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mediapipe as mp
import cv2
import time

cap=cv2.VideoCapture(0)

mpHands=mp.solutions.hands
hands=mpHands.Hands()
mpDraw=mp.solutions.drawing_utils

ptime=0
ctime=0

while True:
  success,img=cap.read()
  if not success:
      break
  imgrgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  results=hands.process(imgrgb)
  #print(results.multi_hand_landmarks)

  if results.multi_hand_landmarks:
      for handLms in results.multi_hand_landmarks:
          for id,lm in enumerate(handLms.landmark):
              #print(id,lm)
              h,w,c=img.shape
              cx,cy=int(lm.x*w),int(lm.y*h)

              if id==0:
                  cv2.circle(img,(cx,cy),25,(255,0,255),cv2.FILLED)

          mpDraw.draw_landmarks(img, handLms, mpHands.HAND_CONNECTIONS)
      
  ctime=time.time()
  fps=1/(ctime-ptime)
  ptime=ctime

  cv2.putText(img,str(int(fps)),(10,70),cv2.FONT_HERSHEY_PLAIN,3,(255,0,255),2)
  cv2.imshow("Image",img)
  if cv2.waitKey(1) & 0xFF == ord("q"):
      break
cap.release()
# Out:
# C:\Users\Sarmili Chanda\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 19
#      17     break
#      18 imgrgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# ---> 19 results=hands.process(imgrgb)
#      20 #print(results.multi_hand_landmarks)
#      22 if results.multi_hand_landmarks:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mediapipe\python\solutions\hands.py:153, in Hands.process(self, image)
#     132 def process(self, image: np.ndarray) -> NamedTuple:
#     133   """Processes an RGB image and returns the hand landmarks and handedness of each detected hand.
#     134
#     135   Args:
#    (...)
#     150          right hand) of the detected hand.
#     151   """
# --> 153   return super().process(input_data={'image': image})
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mediapipe\python\solution_base.py:340, in SolutionBase.process(self, input_data)
#     334   else:
#     335     self._graph.add_packet_to_input_stream(
#     336         stream=stream_name,
#     337         packet=self._make_packet(input_stream_type,
#     338                                  data).at(self._simulated_timestamp))
# --> 340 self._graph.wait_until_idle()
#     341 # Create a NamedTuple object where the field names are mapping to the graph
#     342 # output stream names.
#     343 if self._output_stream_type_info is None:
#
# KeyboardInterrupt:

# %%
import cv2
cap = cv2.VideoCapture(0,cv2.CAP_DSHOW)
print("opened:", cap.isOpened())
success, img = cap.read()
print("read frame:", success, None if img is None else img.shape)
cap.release()
# Out:
# opened: True
# read frame: True (480, 640, 3)
